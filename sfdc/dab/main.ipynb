# %%
# %pip install pyyaml

# %%
import generate_dab_yaml as gdy

sys.argv = [
    "generate_salesforce_pipeline", 
    "/Volumes/yasmok/sfdc_dabs/sfdc_config/example_config.csv",
    "/Workspace/Users/yas.mokri@databricks.com/DE-Accelerators/test_tapworks_sfdc/tapworks_sfdc/resources"
]

gdy.main()
